# %% [markdown]
# Install prequisite packages

# %%
# !pip install --upgrade azureml-sdk opencv-contrib-python
# Out:
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.40.0-py3-none-any.whl (4.5 kB)
# Collecting opencv-contrib-python
#   Downloading opencv_contrib_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (66.7 MB)
#      |████████████████████████████████| 66.7 MB 18.3 MB/s eta 0:00:01
# Collecting azureml-core~=1.40.0
#   Downloading azureml_core-1.40.0.post2-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 87.5 MB/s eta 0:00:01
# Collecting azureml-train-automl-client~=1.40.0
#   Downloading azureml_train_automl_client-1.40.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 87.7 MB/s eta 0:00:01
# Collecting azureml-train-core~=1.40.0
#   Downloading azureml_train_core-1.40.0-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 85.9 MB/s eta 0:00:01
# Collecting azureml-dataset-runtime[fuse]~=1.40.0
#   Downloading azureml_dataset_runtime-1.40.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-pipeline~=1.40.0
#   Downloading azureml_pipeline-1.40.0-py3-none-any.whl (3.7 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3; python_version < "3.7" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from opencv-contrib-python) (1.18.5)
# Requirement already satisfied, skipping upgrade: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.1.27)
# Requirement already satisfied, skipping upgrade: SecretStorage<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (3.3.1)
# Requirement already satisfied, skipping upgrade: msal-extensions<0.4,>=0.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.3.1)
# Requirement already satisfied, skipping upgrade: pyopenssl<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (21.0.0)
# Requirement already satisfied, skipping upgrade: paramiko<3.0.0,>=2.0.8 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2.9.2)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2.8.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-resource<21.0.0,>=15.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (20.0.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-storage<20.0.0,>=16.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (19.0.0)
# Collecting knack~=0.9.0
#   Using cached knack-0.9.0-py3-none-any.whl (59 kB)
# Requirement already satisfied, skipping upgrade: PyJWT<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2.3.0)
# Requirement already satisfied, skipping upgrade: docker<6.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (5.0.3)
# Requirement already satisfied, skipping upgrade: azure-mgmt-containerregistry<9.0.0,>=8.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (8.2.0)
# Requirement already satisfied, skipping upgrade: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.6.4)
# Requirement already satisfied, skipping upgrade: jsonpickle<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2.1.0)
# Requirement already satisfied, skipping upgrade: azure-core<1.22 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.21.1)
# Requirement already satisfied, skipping upgrade: argcomplete<2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.12.3)
# Requirement already satisfied, skipping upgrade: azure-mgmt-keyvault<10.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (9.3.0)
# Requirement already satisfied, skipping upgrade: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (10.0)
# Requirement already satisfied, skipping upgrade: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.5.1)
# Requirement already satisfied, skipping upgrade: urllib3<=1.26.7,>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.26.7)
# Requirement already satisfied, skipping upgrade: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.61.1)
# Requirement already satisfied, skipping upgrade: pkginfo in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.8.2)
# Requirement already satisfied, skipping upgrade: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.61.0)
# Requirement already satisfied, skipping upgrade: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.16.0)
# Requirement already satisfied, skipping upgrade: msrest<1.0.0,>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.6.21)
# Requirement already satisfied, skipping upgrade: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2021.3)
# Requirement already satisfied, skipping upgrade: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (36.0.1)
# Requirement already satisfied, skipping upgrade: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.2.7)
# Requirement already satisfied, skipping upgrade: packaging<22.0,>=20.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (21.3)
# Requirement already satisfied, skipping upgrade: pathspec<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.9.0)
# Requirement already satisfied, skipping upgrade: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (1.0)
# Requirement already satisfied, skipping upgrade: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (2.27.1)
# Requirement already satisfied, skipping upgrade: contextlib2<22.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (21.6.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.40.0->azureml-sdk) (0.10.0)
# Collecting azureml-telemetry~=1.40.0
#   Downloading azureml_telemetry-1.40.0-py3-none-any.whl (31 kB)
# Collecting azureml-automl-core~=1.40.0
#   Downloading azureml_automl_core-1.40.0-py3-none-any.whl (230 kB)
#      |████████████████████████████████| 230 kB 89.0 MB/s eta 0:00:01
# Collecting azureml-train-restclients-hyperdrive~=1.40.0
#   Downloading azureml_train_restclients_hyperdrive-1.40.0-py3-none-any.whl (19 kB)
# Requirement already satisfied, skipping upgrade: pyarrow<4.0.0,>=0.17.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (3.0.0)
# Collecting azureml-dataprep<3.1.0a,>=3.0.0a
#   Downloading azureml_dataprep-3.0.2-py3-none-any.whl (38.6 MB)
#      |████████████████████████████████| 38.6 MB 84.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (3.0.1)
# Collecting azureml-pipeline-core~=1.40.0
#   Downloading azureml_pipeline_core-1.40.0-py3-none-any.whl (313 kB)
#      |████████████████████████████████| 313 kB 86.9 MB/s eta 0:00:01
# Collecting azureml-pipeline-steps~=1.40.0
#   Downloading azureml_pipeline_steps-1.40.0-py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 31.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage<4.0.0->azureml-core~=1.40.0->azureml-sdk) (0.7.1)
# Requirement already satisfied, skipping upgrade: portalocker<3,>=1.0; python_version >= "3.5" and platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions<0.4,>=0.3.0->azureml-core~=1.40.0->azureml-sdk) (2.3.2)
# Requirement already satisfied, skipping upgrade: six>=1.5.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyopenssl<22.0.0->azureml-core~=1.40.0->azureml-sdk) (1.16.0)
# Requirement already satisfied, skipping upgrade: pynacl>=1.0.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.40.0->azureml-sdk) (1.5.0)
# Requirement already satisfied, skipping upgrade: bcrypt>=3.1.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from paramiko<3.0.0,>=2.0.8->azureml-core~=1.40.0->azureml-sdk) (3.2.0)
# Requirement already satisfied, skipping upgrade: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-mgmt-resource<21.0.0,>=15.0.0->azureml-core~=1.40.0->azureml-sdk) (1.3.0)
# Requirement already satisfied, skipping upgrade: tabulate in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.40.0->azureml-sdk) (0.8.9)
# Requirement already satisfied, skipping upgrade: pygments in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.40.0->azureml-sdk) (2.11.2)
# Requirement already satisfied, skipping upgrade: pyyaml in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from knack~=0.9.0->azureml-core~=1.40.0->azureml-sdk) (6.0)
# Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<6.0.0->azureml-core~=1.40.0->azureml-sdk) (1.2.3)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle<3.0.0->azureml-core~=1.40.0->azureml-sdk) (4.8.3)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.40.0->azureml-sdk) (0.4.8)
# Requirement already satisfied, skipping upgrade: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.40.0->azureml-sdk) (0.6.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.40.0->azureml-sdk) (2021.10.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.40.0->azureml-sdk) (1.3.0)
# Requirement already satisfied, skipping upgrade: cffi>=1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.40.0->azureml-sdk) (1.15.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from packaging<22.0,>=20.0->azureml-core~=1.40.0->azureml-sdk) (3.0.6)
# Requirement already satisfied, skipping upgrade: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.40.0->azureml-sdk) (1.0.post1)
# Requirement already satisfied, skipping upgrade: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.40.0->azureml-sdk) (2.0.10)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.40.0->azureml-sdk) (3.3)
# Requirement already satisfied, skipping upgrade: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.40.0->azureml-sdk) (1.7.1)
# Requirement already satisfied, skipping upgrade: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.40.0->azureml-train-automl-client~=1.40.0->azureml-sdk) (0.11.10)
# Requirement already satisfied, skipping upgrade: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<3.1.0a,>=3.0.0a->azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (38.0.0)
# Collecting azureml-dataprep-rslex~=2.4.0dev0
#   Downloading azureml_dataprep_rslex-2.4.3-cp36-cp36m-manylinux1_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 83.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<3.1.0a,>=3.0.0a->azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (2.1.22)
# Requirement already satisfied, skipping upgrade: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<3.1.0a,>=3.0.0a->azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (2.0.0)
# Requirement already satisfied, skipping upgrade: azure-identity==1.7.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<3.1.0a,>=3.0.0a->azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (1.7.0)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.40.0->azureml-sdk) (4.0.1)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.40.0->azureml-sdk) (3.6.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core~=1.40.0->azureml-sdk) (3.1.1)
# Requirement already satisfied, skipping upgrade: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<37.0.0->azureml-core~=1.40.0->azureml-sdk) (2.21)
# Requirement already satisfied, skipping upgrade: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<3.1.0a,>=3.0.0a->azureml-dataset-runtime[fuse]~=1.40.0->azureml-sdk) (1.6.0)
# ERROR: azureml-widgets 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-widgets 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-train 1.38.0 has requirement azureml-train-core~=1.38.0, but you'll have azureml-train-core 1.40.0 which is incompatible.
# ERROR: azureml-train-automl 1.38.0 has requirement azureml-automl-core~=1.38.0, but you'll have azureml-automl-core 1.40.0 which is incompatible.
# ERROR: azureml-train-automl 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-train-automl 1.38.0 has requirement azureml-train-automl-client~=1.38.0, but you'll have azureml-train-automl-client 1.40.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.38.0 has requirement azureml-automl-core~=1.38.0, but you'll have azureml-automl-core 1.40.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.38.0 has requirement azureml-train-automl-client~=1.38.0, but you'll have azureml-train-automl-client 1.40.0 which is incompatible.
# ERROR: azureml-tensorboard 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-responsibleai 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-responsibleai 1.38.0 has requirement azureml-dataset-runtime~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-responsibleai 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-opendatasets 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-opendatasets 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-opendatasets 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-mlflow 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-interpret 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-defaults 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-defaults 1.38.0 has requirement azureml-dataset-runtime[fuse]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement azureml-pipeline-core~=1.38.0, but you'll have azureml-pipeline-core 1.40.0 which is incompatible.
# ERROR: azureml-datadrift 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-contrib-services 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-server 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-reinforcementlearning 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-reinforcementlearning 1.38.0 has requirement azureml-train-core~=1.38.0, but you'll have azureml-train-core 1.40.0 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.38.0 has requirement azureml-dataset-runtime~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.38.0 has requirement azureml-pipeline-core~=1.38.0, but you'll have azureml-pipeline-core 1.40.0 which is incompatible.
# ERROR: azureml-contrib-notebook 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-notebook 1.38.0 has requirement azureml-pipeline-core~=1.38.0, but you'll have azureml-pipeline-core 1.40.0 which is incompatible.
# ERROR: azureml-contrib-fairness 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-dataset 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-contrib-dataset 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-contrib-automl-pipeline-steps 1.38.0 has requirement azureml-pipeline-steps~=1.38.0, but you'll have azureml-pipeline-steps 1.40.0 which is incompatible.
# ERROR: azureml-cli-common 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-cli-common 1.38.0 has requirement azureml-pipeline-core~=1.38.0, but you'll have azureml-pipeline-core 1.40.0 which is incompatible.
# ERROR: azureml-cli-common 1.38.0 has requirement azureml-train-core~=1.38.0; python_version >= "3.5", but you'll have azureml-train-core 1.40.0 which is incompatible.
# ERROR: azureml-automl-runtime 1.38.0 has requirement azureml-automl-core~=1.38.0, but you'll have azureml-automl-core 1.40.0 which is incompatible.
# ERROR: azureml-automl-runtime 1.38.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.38.0, but you'll have azureml-dataset-runtime 1.40.0 which is incompatible.
# ERROR: azureml-automl-dnn-nlp 1.38.0 has requirement azureml-automl-core~=1.38.0, but you'll have azureml-automl-core 1.40.0 which is incompatible.
# ERROR: azureml-automl-dnn-nlp 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# ERROR: azureml-automl-dnn-nlp 1.38.0 has requirement azureml-telemetry~=1.38.0, but you'll have azureml-telemetry 1.40.0 which is incompatible.
# ERROR: azureml-accel-models 1.38.0 has requirement azureml-core~=1.38.0, but you'll have azureml-core 1.40.0.post2 which is incompatible.
# Installing collected packages: knack, azureml-core, azureml-telemetry, azureml-dataprep-rslex, azureml-dataprep, azureml-dataset-runtime, azureml-automl-core, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk, opencv-contrib-python
#   Attempting uninstall: knack
#     Found existing installation: knack 0.8.2
#     Uninstalling knack-0.8.2:
#       Successfully uninstalled knack-0.8.2
#   Attempting uninstall: azureml-core
#     Found existing installation: azureml-core 1.38.0
#     Uninstalling azureml-core-1.38.0:
#       Successfully uninstalled azureml-core-1.38.0
#   Attempting uninstall: azureml-telemetry
#     Found existing installation: azureml-telemetry 1.38.0
#     Uninstalling azureml-telemetry-1.38.0:
#       Successfully uninstalled azureml-telemetry-1.38.0
#   Attempting uninstall: azureml-dataprep-rslex
#     Found existing installation: azureml-dataprep-rslex 2.2.0
#     Uninstalling azureml-dataprep-rslex-2.2.0:
#       Successfully uninstalled azureml-dataprep-rslex-2.2.0
#   Attempting uninstall: azureml-dataprep
#     Found existing installation: azureml-dataprep 2.26.0
#     Uninstalling azureml-dataprep-2.26.0:
#       Successfully uninstalled azureml-dataprep-2.26.0
#   Attempting uninstall: azureml-dataset-runtime
#     Found existing installation: azureml-dataset-runtime 1.38.0
#     Uninstalling azureml-dataset-runtime-1.38.0:
#       Successfully uninstalled azureml-dataset-runtime-1.38.0
#   Attempting uninstall: azureml-automl-core
#     Found existing installation: azureml-automl-core 1.38.0
#     Uninstalling azureml-automl-core-1.38.0:
#       Successfully uninstalled azureml-automl-core-1.38.0
#   Attempting uninstall: azureml-train-restclients-hyperdrive
#     Found existing installation: azureml-train-restclients-hyperdrive 1.38.0
#     Uninstalling azureml-train-restclients-hyperdrive-1.38.0:
#       Successfully uninstalled azureml-train-restclients-hyperdrive-1.38.0
#   Attempting uninstall: azureml-train-core
#     Found existing installation: azureml-train-core 1.38.0
#     Uninstalling azureml-train-core-1.38.0:
#       Successfully uninstalled azureml-train-core-1.38.0
#   Attempting uninstall: azureml-train-automl-client
#     Found existing installation: azureml-train-automl-client 1.38.0
#     Uninstalling azureml-train-automl-client-1.38.0:
#       Successfully uninstalled azureml-train-automl-client-1.38.0
#   Attempting uninstall: azureml-pipeline-core
#     Found existing installation: azureml-pipeline-core 1.38.0
#     Uninstalling azureml-pipeline-core-1.38.0:
#       Successfully uninstalled azureml-pipeline-core-1.38.0
#   Attempting uninstall: azureml-pipeline-steps
#     Found existing installation: azureml-pipeline-steps 1.38.0
#     Uninstalling azureml-pipeline-steps-1.38.0:
#       Successfully uninstalled azureml-pipeline-steps-1.38.0
#   Attempting uninstall: azureml-pipeline
#     Found existing installation: azureml-pipeline 1.38.0
#     Uninstalling azureml-pipeline-1.38.0:
#       Successfully uninstalled azureml-pipeline-1.38.0
#   Attempting uninstall: azureml-sdk
#     Found existing installation: azureml-sdk 1.38.0
#     Uninstalling azureml-sdk-1.38.0:
#       Successfully uninstalled azureml-sdk-1.38.0
# Successfully installed azureml-automl-core-1.40.0 azureml-core-1.40.0.post2 azureml-dataprep-3.0.2 azureml-dataprep-rslex-2.4.3 azureml-dataset-runtime-1.40.0 azureml-pipeline-1.40.0 azureml-pipeline-core-1.40.0 azureml-pipeline-steps-1.40.0 azureml-sdk-1.40.0 azureml-telemetry-1.40.0 azureml-train-automl-client-1.40.0 azureml-train-core-1.40.0 azureml-train-restclients-hyperdrive-1.40.0 knack-0.9.0 opencv-contrib-python-4.5.5.64

# %%
import azureml.core

print("This notebook was created using version 1.35.0 of the Azure ML SDK.")
print("You are currently using version", azureml.core.VERSION, "of the Azure ML SDK.")
assert (
    azureml.core.VERSION >= "1.35"
), "Please upgrade the Azure ML SDK by running '!pip install --upgrade azureml-sdk' then restart the kernel."
# Out:
# This notebook was created using version 1.35.0 of the Azure ML SDK.
# You are currently using version 1.38.0 of the Azure ML SDK.

# %%
# !pip install azure-core azure-storage-blob azure-storage-file-datalake==12.5.0
# Out:
# Requirement already satisfied: azure-core in /home/azureuser/.local/lib/python3.6/site-packages (1.19.0)
# Requirement already satisfied: azure-storage-blob in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (12.10.0b3)
# Requirement already satisfied: azure-storage-file-datalake==12.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (12.5.0)
# Requirement already satisfied: msrest>=0.6.21 in /home/azureuser/.local/lib/python3.6/site-packages (from azure-storage-file-datalake==12.5.0) (0.6.21)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-core) (1.15.0)
# Requirement already satisfied: requests>=2.18.4 in /home/azureuser/.local/lib/python3.6/site-packages (from azure-core) (2.26.0)
# Requirement already satisfied: cryptography>=2.1.4 in /home/azureuser/.local/lib/python3.6/site-packages (from azure-storage-blob) (3.4.8)
# Requirement already satisfied: cffi>=1.12 in /home/azureuser/.local/lib/python3.6/site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest>=0.6.21->azure-storage-file-datalake==12.5.0) (2021.5.30)
# Requirement already satisfied: isodate>=0.6.0 in /home/azureuser/.local/lib/python3.6/site-packages (from msrest>=0.6.21->azure-storage-file-datalake==12.5.0) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/azureuser/.local/lib/python3.6/site-packages (from msrest>=0.6.21->azure-storage-file-datalake==12.5.0) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/azureuser/.local/lib/python3.6/site-packages (from requests>=2.18.4->azure-core) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests>=2.18.4->azure-core) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/azureuser/.local/lib/python3.6/site-packages (from requests>=2.18.4->azure-core) (2.0.7)
# Requirement already satisfied: pycparser in /home/azureuser/.local/lib/python3.6/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.20)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/azureuser/.local/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-file-datalake==12.5.0) (3.1.1)

# %%
import os
import time
import numpy as np
import cv2
from PIL import Image
from datetime import datetime
# from azure.storage.filedatalake._models import ContentSettings
# from azure.storage.filedatalake import DataLakeServiceClient
from azure.storage.blob import BlobServiceClient, ContainerClient, BlobClient 
from azure.core.exceptions import ResourceExistsError

# %%
# Variable inputs
file_name = "BigBuckBunny.mp4"
file_path = "/home/azureuser/cloudfiles/code/Users/jocoons/AML_Labeler_Demo/video_files"
full_file_path = os.path.join(file_path, file_name)
frame_count = 0

# %%
# Create ADL G2 or Blob Storage Client
fs_name = "video2frames"
dir_name = os.path.basename(full_file_path).split('.')[0]
dir_name = str.lower(dir_name)
# adl_g2_conn_str = "DefaultEndpointsProtocol=https;AccountName=aiotstorage;AccountKey=qxSjMtsutNzRt9cwsqre67DHNP15eTFpU7B4UqSJILW+ZGYdyyrllG391FDOTstpCpTrYhO1zYv7LwUnJu5d8w==;EndpointSuffix=core.windows.net"
blob_conn_str = "DefaultEndpointsProtocol=https;AccountName=aiotblob;AccountKey=ePg06oWtznc5XnlDW2hI34y0q27GOLw6RczpbKaz0U2NaBCN5WfQQBaBwacROIPcBLm1T+f8uoNscHzebd5K9Q==;EndpointSuffix=core.windows.net"
# storage_client = DataLakeServiceClient.from_connection_string(adl_g2_conn_str)
storage_client = BlobServiceClient.from_connection_string(blob_conn_str)

# %%
#  Create Blob Container
def create_container(base_dir):
    global container_client
    try:
        container_client = storage_client.create_container(base_dir)
    
    except ResourceExistsError as e:
        # print(e)
        container_client = storage_client.get_container_client(base_dir)

create_container(fs_name)

# %%
# Create ADL G2 File System (base container)
# def create_file_system(base_dir):
#     global file_system_client
#     try:

#         file_system_client = storage_client.create_file_system(file_system=base_dir)
    
#     except ResourceExistsError as e:

#         file_system_client = storage_client.get_file_system_client(base_dir)

# # Create directory in ADL G2
# def create_directory(target_dir):
#     global directory_client
#     try:
#         directory_client = file_system_client.create_directory(target_dir)
    
#     except ResourceExistsError as e:

#         directory_client = file_system_client.get_directory_client(target_dir)

# create_file_system(fs_name)
# create_directory(dir_name)

# %%
# def cap_video_file():
vid_cap = cv2.VideoCapture(full_file_path)
if not vid_cap.isOpened():
    print('Cannot open file')

# Capture individual frames
while(vid_cap.isOpened()):
    _, frame = vid_cap.read()
    if _ == True:
        frame_count += 1
        # Show frame size
        h, w = frame.shape[:2]
        print("\n\n Frame height = {} \n Frame width = {} \n\n ".format(h,w))
        
        # create naming structure
        now = datetime.now()  
        filetime = now.strftime("%Y%d%m%H%M%S%f")
        frame_num = str(frame_count).zfill(6)
        frame_file_name = f"Frame{frame_num}-{filetime}-raw.jpg"
        frame_encoded = cv2.imencode(".jpg", frame)[1].tobytes()
        
        # ADL G2 code
        # try:
        #     file_client = directory_client.create_file(frame_file_name)
        #     file_client.append_data(data=frame_encoded, offset=0, length=len(frame_encoded))
        #     file_client.flush_data(len(frame_encoded))
        #     print(f"Uploaded image: {frame_file_name}")

        # except Exception as e:
        #     print(e)

        # Blob code 
        try:
            blob_client = container_client.get_blob_client(f"{dir_name}/{frame_file_name}")       
            blob_client.upload_blob(frame_encoded, blob_type="BlockBlob")
            print(f"Successfully uploaded {frame_file_name}")
        except Exception as e:
            print(e)
# Out:
#  Frame height = 180
#  Frame width = 320
#
#
# Successfully uploaded Frame000001-20221602193942794561-raw.jpg
#
#
#  Frame height = 180
#  Frame width = 320
#
#
# Successfully uploaded Frame
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_upload_helpers.py in upload_block_blob(client, data, stream, length, overwrite, headers, validate_content, max_concurrency, blob_settings, encryption_options, **kwargs)
#     111                 immutability_policy_mode=immutability_policy_mode,
#     112                 legal_hold=legal_hold,
# --> 113                 **kwargs)
#     114
#     115         use_original_upload_path = blob_settings.use_byte_buffer or \
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_generated/operations/_block_blob_operations.py in upload(self, content_length, body, timeout, transactional_content_md5, metadata, tier, request_id_parameter, blob_tags_string, immutability_policy_expiry, immutability_policy_mode, legal_hold, blob_http_headers, lease_access_conditions, cpk_info, cpk_scope_info, modified_access_conditions, **kwargs)
#     239         body_content_kwargs['stream_content'] = body
#     240         request = self._client.put(url, query_parameters, header_parameters, **body_content_kwargs)
# --> 241         pipeline_response = self._client._pipeline.run(request, stream=False, **kwargs)
#     242         response = pipeline_response.http_response
#     243
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in run(self, request, **kwargs)
#     209             else _TransportRunner(self._transport)
#     210         )
# --> 211         return first_node.send(pipeline_request)  # type: ignore
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/policies/_redirect.py in send(self, request)
#     156         redirect_settings = self.configure_redirects(request.context.options)
#     157         while retryable:
# --> 158             response = self.next.send(request)
#     159             redirect_location = self.get_redirect_location(response)
#     160             if redirect_location and redirect_settings['allow']:
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_shared/policies.py in send(self, request)
#     501         while retries_remaining:
#     502             try:
# --> 503                 response = self.next.send(request)
#     504                 if is_retry(response, retry_settings['mode']):
#     505                     retries_remaining = self.increment(
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_shared/policies.py in send(self, request)
#     302             request.context.options.pop('raw_response_hook', self._response_callback)
#     303
# --> 304         response = self.next.send(request)
#     305         will_retry = is_retry(response, request.context.options.get('mode'))
#     306         if not will_retry and download_stream_current is not None:
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#      69         _await_result(self._policy.on_request, request)
#      70         try:
# ---> 71             response = self.next.send(request)
#      72         except Exception:  # pylint: disable=broad-except
#      73             if not _await_result(self._policy.on_exception, request):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/_base.py in send(self, request)
#     101         return PipelineResponse(
#     102             request.http_request,
# --> 103             self._sender.send(request.http_request, **request.context.options),
#     104             context=request.context,
#     105         )
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_shared/base_client.py in send(self, request, **kwargs)
#     331
#     332     def send(self, request, **kwargs):
# --> 333         return self._transport.send(request, **kwargs)
#     334
#     335     def open(self):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azure/storage/blob/_shared/base_client.py in send(self, request, **kwargs)
#     331
#     332     def send(self, request, **kwargs):
# --> 333         return self._transport.send(request, **kwargs)
#     334
#     335     def open(self):
#
# ~/.local/lib/python3.6/site-packages/azure/core/pipeline/transport/_requests_basic.py in send(self, request, **kwargs)
#     313                 cert=kwargs.pop('connection_cert', self.connection_config.cert),
#     314                 allow_redirects=False,
# --> 315                 **kwargs)
#     316
#     317         except (urllib3.exceptions.NewConnectionError, urllib3.exceptions.ConnectTimeoutError) as err:
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/.local/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /anaconda/envs/azureml_py36/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /anaconda/envs/azureml_py36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda/envs/azureml_py36/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /anaconda/envs/azureml_py36/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /anaconda/envs/azureml_py36/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
